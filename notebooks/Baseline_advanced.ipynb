# %% [markdown]
# # Baseline Model - Heart Disease Prediction

# %%
import sys
sys.path.append('..')

from src.pipelines.utils import load_config
from src.pipelines.feature_eng_pipeline import build_features
from src.pipelines.training_pipeline import train

config = load_config('../config/advanced/local.yaml')

# %%
df_features = build_features(config)
df_features.head()

# %%
model, metrics = train(config)
metrics
